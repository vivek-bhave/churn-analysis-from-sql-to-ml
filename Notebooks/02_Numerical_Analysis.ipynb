# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Data/Cleaned/customer_churn_dataset.csv",index_col=0)
df.head()
# Out:
#              Age  Gender  Tenure  Usage Frequency  Support Calls  \
# CustomerID
# 1.0         22.0  Female    25.0             14.0            4.0
# 2.0         30.0  Female    39.0             14.0            5.0
# 2.0         41.0  Female    28.0             28.0            7.0
# 3.0         47.0    Male    27.0             10.0            2.0
# 3.0         65.0  Female    49.0              1.0           10.0
#
#             Payment Delay Subscription Type Contract Length  Total Spend  \
# CustomerID
# 1.0                  27.0             Basic         Monthly        598.0
# 2.0                  18.0          Standard          Annual        932.0
# 2.0                  13.0          Standard         Monthly        584.0
# 3.0                  29.0           Premium          Annual        757.0
# 3.0                   8.0             Basic         Monthly        557.0
#
#             Last Interaction  Churn
# CustomerID
# 1.0                      9.0    1.0
# ...

# %% [markdown]
# #

# %%
df["Churn"].value_counts()
# Out:
# Churn
# 1.0    280492
# 0.0    224714
# Name: count, dtype: int64
