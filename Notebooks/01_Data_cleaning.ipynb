# %%
import pandas as pd
import numpy as np

# %%
df_test = pd.read_csv("../Data/Raw/customer_churn_dataset-testing-master.csv")
df_train = pd.read_csv("../Data/Raw/customer_churn_dataset-training-master.csv")

# %%
df_train.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
df = pd.concat([df_train,df_test])
df = df.sort_values(by="CustomerID")
df = df.set_index("CustomerID")

# %%
df
# Out:
#              Age  Gender  Tenure  Usage Frequency  Support Calls  \
# CustomerID
# 1.0         22.0  Female    25.0             14.0            4.0
# 2.0         30.0  Female    39.0             14.0            5.0
# 2.0         41.0  Female    28.0             28.0            7.0
# 3.0         47.0    Male    27.0             10.0            2.0
# 3.0         65.0  Female    49.0              1.0           10.0
# ...          ...     ...     ...              ...            ...
# 449996.0    25.0  Female     8.0             13.0            1.0
# 449997.0    26.0    Male    35.0             27.0            1.0
# 449998.0    28.0    Male    55.0             14.0            2.0
# 449999.0    31.0    Male    48.0             20.0            1.0
# NaN          NaN     NaN     NaN              NaN            NaN
#
#             Payment Delay Subscription Type Contract Length  Total Spend  \
# CustomerID
# 1.0                  27.0             Basic         Monthly       598.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 505207 entries, 1.0 to nan
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Age                505206 non-null  float64
#  1   Gender             505206 non-null  object
#  2   Tenure             505206 non-null  float64
#  3   Usage Frequency    505206 non-null  float64
#  4   Support Calls      505206 non-null  float64
#  5   Payment Delay      505206 non-null  float64
#  6   Subscription Type  505206 non-null  object
#  7   Contract Length    505206 non-null  object
#  8   Total Spend        505206 non-null  float64
#  9   Last Interaction   505206 non-null  float64
#  10  Churn              505206 non-null  float64
# dtypes: float64(8), object(3)
# memory usage: 46.3+ MB

# %%
df.isnull().sum()
# Out:
# Age                  1
# Gender               1
# Tenure               1
# Usage Frequency      1
# Support Calls        1
# Payment Delay        1
# Subscription Type    1
# Contract Length      1
# Total Spend          1
# Last Interaction     1
# Churn                1
# dtype: int64

# %%
df.shape
# Out:
# (505207, 11)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (505206, 11)

# %%
df.to_csv("../Data/Cleaned/customer_churn_dataset.csv")
